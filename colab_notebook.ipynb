# %% [markdown]
# # NeuroSeg-U BraTS 2020 Colab Run
#
# This notebook installs the repo, validates the dataset, and starts training on BraTS 2020.

# %%
# !git clone https://github.com/showravj2-create/Nuroserg_U_r.git
# %cd Nuroserg_U_r
# !pip install -q -r requirements.txt

# %%
from google.colab import drive
drive.mount('/content/drive')
print('Mounted Drive. Move or copy your BraTS 2020 folder into /content/BraTS2020')

# %%
# !ls /content
# !ls /content/BraTS2020 2>/dev/null || echo 'Dataset not found yet. Place it at /content/BraTS2020 before training.'

# %%
# !python scripts/check_brats_dataset.py --data-root /content/BraTS2020

# %%
# !python scripts/train.py --config configs/brats_2p5d.yaml
